# %% [markdown]
# <a href="https://colab.research.google.com/github/naavsaa/Hactiv8-Python/blob/master/Pertemuan_5_(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![Screen Shot 2021-10-07 at 19.09.47.png](data:image/png;base64,...)

# %%
df_nba = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
print(f"banyaknya baris : {len(df_nba)}")
print(f"baris x kolom   : {df_nba.shape}")
# Out:
# banyaknya baris : 126314
# baris x kolom   : (126314, 23)

# %%
df_nba.head() # mengambil paling atas bisa dilihat di sini juga https://docs.google.com/spreadsheets/d/1qqjyz6hVJTP35aAXrWd46idx5mpguEUo5lh0BmH8BUg/edit?usp=sharing
# Out:
#    gameorder       game_id  ... forecast  notes
# 0          1  194611010TRH  ...     0.64    NaN
# 1          1  194611010TRH  ...     0.36    NaN
# 2          2  194611020CHS  ...     0.63    NaN
# 3          2  194611020CHS  ...     0.37    NaN
# 4          3  194611020DTF  ...     0.64    NaN
#
# [5 rows x 23 columns]

# %%
pd.set_option("display.max.columns",None)
pd.set_option("display.precision",2)

# %%
df_nba.tail(3) ## mengambil paling bawah bisa dilihat di sini juga https://docs.google.com/spreadsheets/d/1qqjyz6hVJTP35aAXrWd46idx5mpguEUo5lh0BmH8BUg/edit?usp=sharing
# Out:
#         gameorder       game_id  ... forecast  notes
# 126311      63156  201506140GSW  ...     0.23    NaN
# 126312      63157  201506170CLE  ...     0.48    NaN
# 126313      63157  201506170CLE  ...     0.52    NaN
#
# [3 rows x 23 columns]

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df_nba["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# PIT      60
# INJ      60
# DTF      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df_nba["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
#pandas syntax : 
df_nba.loc[df["fran_id"]=="Lakers","team_id"].value_counts()

#SQL syntax : SELECT fran_id, team_id, count() WHERE fran_id = "Lakers" group by 1,2
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
#pandas syntax : 

df_nba.loc[df["team_id"]=="MNL","date_game"].min()

#SQL syntax : SELECT date_game WHERE team_id == MNL ORDER BY date_game ASC LIMIT 1
# Out:
# '1/1/1949'

# %%
# yang lainnya bisa dicoba sendiri ya

# %%
# pandas from scratch

revenues = pd.Series([5555,7000,1980])
print(revenues)

# SELECT kolom FROM revenues


city_revenues = pd.Series([4200,8000,6500],index = ["Amsterdam","Toronto","Tokyo"])
print(city_revenues)
# SELECT kolom1,kolom 2 FROM city_revenues


city_employee_count = pd.Series({"Amsterdam":5,"Tokyo":8})
print(city_employee_count)
# SELECT kolom1,kolom 2 FROM city_employee_count

print("Tokyo" in city_employee_count)

print("New York" in city_employee_count)

# bisa dicoba sendiri ya
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64
# Amsterdam    5
# Tokyo        8
# dtype: int64
# True

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba = df.copy()
nba.shape
#menambahkan 1 kolom baru
nba["difference"] = df.pts - df.opp_pts

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
rows_without_missing_data = nba.dropna()
rows_without_missing_data 

#SELECT * FROM rows_without_missing_data WHERE notes not null
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
# kalau yang dropna() axis = 1 bisa dicoba sendiri ya

data_without_missing_columns = nba.dropna(axis=1)

# %%
#invalid values

nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')].empty

#(SELECT * 
# FROM NBA 
# WHERE pts > opp_pts AND game_result != W) is empty

# untuk merge bisa dicoba sendiri 
# jadi initinya kita menggabungkan beberapa DF kalau di SQL = JOIN
# Out:
# True

# %%
# %matplotlib inline

nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba[nba["fran_id"]=="Knicks"].groupby("year_id")["pts"].sum("year_id").plot()

# %%
data_pandas_query = nba[nba["fran_id"]=="Knicks"].groupby("year_id")["pts"] #pts adalah yang akan ditampilkan

#mengapa tidak bisa pakai [] itu karena akan ada perbedaan makna / syntax
#SQL = SELECT SUM(PTS) FROM NBA WHERE FRAN_ID = "KNICKS" GROUP BY YEAR_ID

data_pandas_query.sum("year_id").plot(kind="bar")
