# %% [markdown]
# <a href="https://colab.research.google.com/github/naavsaa/Hactiv8-Python/blob/master/Hactiv8/Pertemuan_10_Inferential_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
#from IPyhton.display import Image

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(5,5)})

#Statistics Library
from scipy.stats import uniform

#create sample data
n=10000
start = 10
width = 20
data_uniform = uniform.rvs(size = n, loc=start,scale=width)

ax = sns.distplot(data_uniform,
                 bins=100,
                 kde=True, 
                 color = 'skyblue',
                 hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel='Uniform Distribution ',ylabel='Frequency')

#contohnya adalah kadar SpO2 dalam darah
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Uniform Distribution ')]

# %%
from scipy.stats import norm
data_normal = norm.rvs(size = 10000,loc=0,scale=1)

ax=sns.distplot(data_normal,
                bins=100,
                kde=True,
                color='skyblue',
                hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel = 'Normal Distribution',ylabel = 'Frequency')

#contohnya adalah tinggi badan
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a=5,size=10000)

ax=sns.distplot(data_gamma,
                kde=True,
                bins=100,
                color='skyblue',
                hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel = 'Gamma Distribution',ylabel = 'Frequency')

#contohnya adalah ....
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Gamma Distribution')]

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1,loc=0,size=1000)

ax=sns.distplot(data_expon,
                kde=True,
                bins=100,
                color='skyblue',
                hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel = 'Exponential Distribution',ylabel = 'Frequency')

#contohnya adalah pembelahan sel
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Exponential Distribution')]

# %%
from scipy.stats import poisson
data_poisson = expon.rvs(scale=1,loc=0,size=1000)

ax=sns.distplot(data_poisson,
                kde=True,
                bins=100,
                color='skyblue',
                hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel = 'Poisson Distribution',ylabel = 'Frequency')

#contohnya adalah ....
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Distribution')]

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)

ax=sns.distplot(data_binom,
                kde=False,
                bins=100,
                color='skyblue',
                hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel = 'Binomial Distribution',ylabel = 'Frequency')

#contohnya adalah sukses or failure
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binomial Distribution')]

# %%
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.6)

ax=sns.distplot(data_bern,
                kde=False,
                bins=100,
                color='skyblue',
                hist_kws={"linewidth":15,'alpha':1})

ax.set(xlabel = 'bernoulli Distribution',ylabel = 'Frequency')

#contohnya adalah lemparan koin
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'bernoulli Distribution')]

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('heart.csv')
print(df)
# Out:
#       age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  target
# 0      52    1   0       125   212  ...      1.0      2   2     3       0
# 1      53    1   0       140   203  ...      3.1      0   0     3       0
# 2      70    1   0       145   174  ...      2.6      0   0     3       0
# 3      61    1   0       148   203  ...      0.0      2   1     3       0
# 4      62    0   0       138   294  ...      1.9      1   3     2       0
# ...   ...  ...  ..       ...   ...  ...      ...    ...  ..   ...     ...
# 1020   59    1   1       140   221  ...      0.0      2   0     2       1
# 1021   60    1   0       125   258  ...      2.8      1   1     3       0
# 1022   47    1   0       110   275  ...      1.0      1   1     2       0
# 1023   50    0   0       110   254  ...      0.0      2   0     2       1
# 1024   54    1   0       120   188  ...      1.4      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df['Sex1'] = df.sex.replace({1:"Male",0:"Female"})
dx = df[["target","Sex1"]].dropna()
pd.crosstab(dx.target,dx.Sex1)
# Out:
# Sex1    Female  Male
# target
# 0           86   413
# 1          226   300

# %%
p_fm = 226/(86+226)
p_fm
# Out:
# 0.7243589743589743

# %%
n = 86 + 226
n
# Out:
# 312

# %%
se_female = np.sqrt(p_fm * (1-p_fm)/n)
se_female
#0.25 - > 1.96

z_score = 1.96
lcb = p_fm - z_score * se_female
ucp = p_fm + z_score * se_female 
print(f"{lcb} {ucp}")

import statsmodels.api as sm
sm.stats.proportion_confint(n* p_fm,n)
# Out:
# 0.6747765651256307 0.773941383592318
# (0.6747774762140357, 0.773940472503913)

# %%
#Confidence Interval

df.groupby("Sex1").agg({"chol":[np.mean,np.std, np.size]})

mean_fe = 261.45
sd = 64.4
n=312
z=1.96

#standard error
se = sd/np.sqrt(n)

lcb = mean_fe - z* se
ucb = mean_fe + z* se

print(f"{lcb} {ucb}")
# Out:
# 254.3039731821066 268.59602681789335

# %%
import pandas as pd
import seaborn as sns 
import scipy.stats as stats
import numpy as np
import random
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(rc={'figure.figsize':(13,7.5)})
sns.set_context('talk')

#Generate Data of People's Mass in pounds

np.random.seed(42)
normal_distribution_us_male_mass_pounds = np.random.normal(loc=181,scale=24,size=6000)
normal_distribution_us_female_mass_pounds = np.random.normal(loc=132,scale=22,size=6500)
all_mass_Values = np.concatenate((normal_distribution_us_male_mass_pounds,
                                  normal_distribution_us_female_mass_pounds),axis=0)

df_ppl_mass = pd.DataFrame(data={'us_people_mass_pounds':all_mass_Values})

df_ppl_mass.head()

sns.distplot(df_ppl_mass['us_people_mass_pounds'],
             color = "darkslategrey")
plt.xlabel("mass [pounds]",labelpad=14)
plt.ylabel("probability of occurence",labelpad=14)
plt.title("Distribution of Mass of people in U.S",y=1.015,fontsize=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Calculaton Population Mean
pop_mean_mass = df_ppl_mass['us_people_mass_pounds'].mean()
pop_mean_mass

pop_std_dev_mass = df_ppl_mass['us_people_mass_pounds'].std()
pop_std_dev_mass

#sampling data from 12500 data we will make 300 of them samples
sample_means = []
n=25 

for sample in range(0,300):
  sample_values = np.random.choice(a=df_ppl_mass['us_people_mass_pounds'],size=n)
  sample_mean=np.mean(sample_values)
  sample_means.append(sample_mean)

sns.distplot(sample_means)
plt.title("Distribution of Sample Means ($n=25$) of People's Mass in Pounds",y=1.015,fontsize=20)
plt.xlabel("sample mean mass [pounds]",labelpad=14)
plt.ylabel("frequency of occurance",labelpad=14)

#population / all data

median_of_sample_means = np.median(sample_means)
median_of_sample_means


mean_of_sample_means = np.mean(sample_means)
mean_of_sample_means

print(f"""
Population sample : {pop_mean_mass}

""")


#standard deviation of Sample Means

std_dev_of_sample_means = np.std(sample_means)
print(f"""STD DEV : {std_dev_of_sample_means}
      
      """)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Population sample : 155.4232805942338
#
#
# STD DEV : 6.013772034864185

# %%
#critical z scores batas kiri dan batas kanan populasi

standard_error = pop_std_dev_mass / np.sqrt(n)

tail = 1 - stats.norm.cdf(1.96)
1-(tail*2)

lower_95_perc_bound = mean_of_sample_means - 1.96 * standard_error
uppper_95_perc_bound = mean_of_sample_means + 1.96 * standard_error

# %%
kde = stats.gaussian_kde(sample_means)
pos = np.linspace (np.min(sample_means), np.max(sample_means),10000)
plt.plot(pos,kde(pos), color = 'teal')
shade = np.linspace(lower_95_perc_bound,uppper_95_perc_bound,300)
plt.fill_between(shade,kde(shade),alpha = 0.45, color = 'teal',)

plt.text(x=154, y=.01, 
         horizontalalignment = 'center',
         fontsize = 17, 
         s="95% sample means fall within\n this shaded area of plus or minus\n 1.96 z-scores from the mean",
         bbox = dict(facecolor = 'whitesmoke',boxstyle="round, pad=0.1"))

plt.title("Distribution of Sample Means ($n=25$) of People's Mass in Pounds", y=1.015, fontsize = 20)
plt.xlabel("sample mean mass [pounds]", labelpad=14)
plt.ylabel("frequency od occurance",labelpad=14);

# %%
# Calculate p value to prove hypotesis A, B, OR C

import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
n = 1018
#null hypothesis
pnull = .52
#altrenate hypotesis (bertambah)
phat = .56

#define z test 
sm.stats.proportions_ztest(phat*n, n, pnull, alternative = 'larger')

#terbukti bahwa bertambah
#(2.571067795759113, 0.005069273865860533)
# Out:
# (2.571067795759113, 0.005069273865860533)

# %%
#hasil survey apakah BMI laki-laki lebih tinggi dari perempuan
url = "https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nhanes_2015_2016.csv"
da = pd.read_csv(url)
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  ...  BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0  83732     1.0     NaN     1.0  ...     43.6     35.9     101.1     2.0
# 1  83733     1.0     NaN     6.0  ...     40.0     33.2     107.9     NaN
# 2  83734     1.0     NaN     NaN  ...     37.0     31.0     116.5     2.0
# 3  83735     2.0     1.0     1.0  ...     37.7     38.3     110.1     2.0
# 4  83736     2.0     1.0     1.0  ...     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
females = da[da["RIAGENDR"] == 2]
male    = da[da["RIAGENDR"] == 1] 

#n1 = MALE
n1 = len(females)
mu1 = females["BMXBMI"].mean()
sd1 = females["BMXBMI"].std()

#n2 = FEMALE
n2 = len(male)
mu2 = male["BMXBMI"].mean()
sd2 = male["BMXBMI"].std()

#TESTING HASIL SURVEY
sm.stats.ztest(females["BMXBMI"].dropna(),
male["BMXBMI"].dropna(),alternative='two-sided'
)

#dengan hasil (6.1755933531383205, 6.591544431126401e-10)
#karena sangat kecil maka reject null hypothesis
#tidak terbukti bahwa laki laki memiliki body mas index lebih rendah daripada perempuan

plt.figure(figsize=(7,4))
plt.title("Female BMI histogram",fontsize = 16 )
plt.hist(females["BMXBMI"].dropna(),edgecolor = 'k',color = 'pink', bins=25)
plt.show()

plt.figure(figsize=(7,4))
plt.title("Male BMI histogram",fontsize = 16 )
plt.hist(male["BMXBMI"].dropna(),edgecolor = 'k',color = 'blue', bins=25)
plt.show()

# %%
#Hypotesis tentang penyakit jantung. 
#penduduk irlandia yang berpenyakit jantung adalah 42%.
#apakah di US orang-orang lebih banyak terkena penyakit jantung

# %%
#step 1 
#h0 : p0 = 0.42 null hypothesis, 
#ha : p> 0.42   alternate hypothesis

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import scipy.stats.distributions as dist

df= pd.read_csv('heart.csv')

p_us = len (df[df['target']=='1'])/len(df)
se = np.sqrt(0.42 * (1-0.42)/len(df))

#best estimate
be = p_us

#hypothesized estimate
he = 0.42
test_stat = (be-he)/se

#complete test statitics 

se = np.sqrt(0.42 * (1-0.42) / len(df))

be = p_us

he=0.42
test_stat = (be-he)/se

pvalue = 2*dist.norm.cdf(-np.abs(test_stat))

print(f"{pvalue}")

#nilai nya adalah 1.9517162972676465e-163
#jadi tersimpulkan bahwa di amerika lebih banyak orang yang terkena penyakit jantung
# Out:
# 1.9517162972676465e-163
