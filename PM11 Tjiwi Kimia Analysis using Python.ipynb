# %%
import pandas as pd

# %%
tk11 = pd.read_excel(r"C:\Users\id_anm\OneDrive - BTG Group\Desktop\BTG\Customer\Tjiwi Kimia\PM11\DCS Data PM11.xlsx")

# %%
###
Periode 1 pre-installation sensor: 1 mar 2021-30 april 2021
Periode 2 after installation sensor: 9 may 2021-30 june 2021
Periode 3 After cs tunning: 1 july-30 september
#####

# %%
print (tk11)
# Out:
#                Description CONSIST.SAVE ALL STOCK CHEST  \
# 0                     TIME                    308cc0320
# 1      2021-03-01 00:00:00                     3.993914
# 2      2021-03-01 00:05:00                     3.997356
# 3      2021-03-01 00:10:00                     3.992743
# 4      2021-03-01 00:15:00                      3.99404
# ...                    ...                          ...
# 60658                  NaN                          NaN
# 60659                  NaN                          NaN
# 60660                  NaN                          NaN
# 60661                  NaN                          NaN
# 60662                  NaN                          NaN
#
#       STOCK FLOW TO SILO (BW) LEVEL SAVE ALL STOCK CHEST  \
# 0                   308FC0110                  308LC0320
# 1                  372.186127                  49.953979
# 2                  373.698669                  49.648041
# 3                  373.841553                  49.588306
# ...

# %%
len(tk11)
# Out:
# 60663

# %%
tk11.shape
# Out:
# (60663, 76)

# %%
tk11.head()
# Out:
#            Description CONSIST.SAVE ALL STOCK CHEST STOCK FLOW TO SILO (BW)  \
# 0                 TIME                    308cc0320               308FC0110
# 1  2021-03-01 00:00:00                     3.993914              372.186127
# 2  2021-03-01 00:05:00                     3.997356              373.698669
# 3  2021-03-01 00:10:00                     3.992743              373.841553
# 4  2021-03-01 00:15:00                      3.99404              374.794342
#
#   LEVEL SAVE ALL STOCK CHEST CONSISTENCY BLEND CHEST  \
# 0                  308LC0320               408CC0110
# 1                  49.953979                2.994898
# 2                  49.648041                2.990495
# 3                  49.588306                3.002166
# 4                  49.572556                 2.98744
#
#   MACHINE CHEST CONSISTENCY FLOW SAVE ALL SWEETNER FEED PP  \
# 0                 408CC0210                      408FC0110
# 1                  3.214901                      28.182932
# ...

# %%
tk11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60663 entries, 0 to 60662
# Data columns (total 76 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Description                     60608 non-null  object
#  1   CONSIST.SAVE ALL STOCK CHEST    60608 non-null  object
#  2   STOCK FLOW TO SILO (BW)         60608 non-null  object
#  3   LEVEL SAVE ALL STOCK CHEST      60609 non-null  object
#  4   CONSISTENCY BLEND CHEST         60610 non-null  object
#  5   MACHINE CHEST CONSISTENCY       60610 non-null  object
#  6   FLOW SAVE ALL SWEETNER FEED PP  60617 non-null  object
#  7   FLOW CONTROL - DRY BROKE        60617 non-null  object
#  8   FLOW CONTROL - WET BROKE        60618 non-null  object
#  9   FLOW CONTROL - LBKP             60618 non-null  object
#  10  FLOW CONTROL - NBKP             60620 non-null  object
#  11  LEVEL BLEND CHEST               60620 non-null  object
# ...

# %%
tk11.describe()
# Out:
#                 Description  CONSIST.SAVE ALL STOCK CHEST  \
# count                 60608                  60608.000000
# unique                60608                  57202.000000
# top     2021-03-31 05:35:00                      2.498269
# freq                      1                    192.000000
#
#         STOCK FLOW TO SILO (BW)  LEVEL SAVE ALL STOCK CHEST  \
# count                     60608                       60609
# unique                    59647                       55272
# top                           0                           0
# freq                         40                         476
#
#         CONSISTENCY BLEND CHEST  MACHINE CHEST CONSISTENCY  \
# count                   60610.0                    60610.0
# unique                  57361.0                    57642.0
# top                         2.5                        2.5
# freq                      254.0                     2078.0
#
#         FLOW SAVE ALL SWEETNER FEED PP  FLOW CONTROL - DRY BROKE  \
# ...

# %%
import fbprophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-4f89f47c1bda> in <module>
# ----> 1 import fbprophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
print('Prophet %s' % fbprophet.__version__)

# %%
print ("a")
